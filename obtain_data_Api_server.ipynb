# %%
import requests
import pandas as pd
import numpy as np
from tabulate import tabulate



def get_api_data(url, headers=None):
    try:
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            # Assuming the API returns JSON data, you can access it using the .json() method.
            data = response.json()
            return data
        else:
            print(f"Request failed with status code: {response.status_code}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error occurred during the request: {e}")
        return None

# Replace 'https://api.example.com/data' with the actual API endpoint URL.
api_url = 'http://127.0.0.1:3001/logdata/vehicle/list/10'

# Define your custom headers as a dictionary.
custom_headers = {
    'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIjoiYWRtaW4iLCJwZXJtaXNzaW9ucyI6WyIvYWRtaW4vKiJdLCJlbWFpbCI6Im5venN5eXp3QHJvZ2Vycy5jYSIsImlhdCI6MTY5MjExNTExNCwiZXhwIjoxNjkyNjMzNTE0fQ.ehJPmsYH0M28NtxA-LHQkSEt6MXrPoG8dU_bppYG9UE',  # Example authorization header
    'Content-Type': 'application/json',  # Example content-type header
    'url' : '/admin/vehicle'
    
}

api_data = get_api_data(api_url, headers=custom_headers)

if api_data:
    column_names = ['Vin', 'Make', 'Model' , 'trim','year', 'scannerID','userEmail' , 'dealerEmail','logActive' ,'uploadInterval', 'logInterval' ]
    df = pd.DataFrame(np.nan, index=[], columns=column_names)
    for idx, x in enumerate(api_data['data']):
        df.loc[idx+1, 'Vin'] = x['vehicleInfo']['vin']
        df.loc[idx+1, 'Make'] = x['vehicleInfo']['make']
        df.loc[idx+1, 'Model'] = x['vehicleInfo']['model']
        df.loc[idx+1, 'trim'] = x['vehicleInfo']['trim']
        df.loc[idx+1, 'year'] = x['vehicleInfo']['year']
        df.loc[idx+1, 'scannerID'] = x['vehicleInfo']['scannerID']
        df.loc[idx+1, 'userEmail'] = x['userEmail']
        df.loc[idx+1, 'dealerEmail'] = x['dealerEmail']
        df.loc[idx+1, 'logActive'] = x['logInfo']['logActive']
        df.loc[idx+1, 'uploadInterval'] = x['logInfo']['uploadInterval']
        df.loc[idx+1, 'logInterval'] = x['logInfo']['logInterval']
    
    
    
table_str = tabulate(df, headers='keys', tablefmt='fancy_grid')

print(table_str)
# for v in api_data['data']:
#     print (v)
# Out:
# ╒════╤════════════╤═══════════╤════════════════╤════════╤════════╤═══════════════════╤══════════════════════╤════════════════════════════╤═════════════╤══════════════════╤═══════════════╕
# │    │ Vin        │ Make      │ Model          │ trim   │   year │ scannerID         │ userEmail            │ dealerEmail                │ logActive   │   uploadInterval │   logInterval │
# ╞════╪════════════╪═══════════╪════════════════╪════════╪════════╪═══════════════════╪══════════════════════╪════════════════════════════╪═════════════╪══════════════════╪═══════════════╡
# │  1 │ 2C4RC1N74K │ CHEVROLET │ MODEL Y        │ C      │   2023 │ A2:AB:C9:E8:18:BA │ gdntvjhd@hotmail.com │ info@greenautosales.com    │ True        │               35 │            19 │
# ├────┼────────────┼───────────┼────────────────┼────────┼────────┼───────────────────┼──────────────────────┼────────────────────────────┼─────────────┼──────────────────┼───────────────┤
# ...

# %%
# Replace 'https://api.example.com/data' with the actual API endpoint URL.
api_url = 'http://127.0.0.1:3001/logdata/obd2ts/list'

# Define your custom headers as a dictionary.
custom_headers = {
    'Authorization': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJyb2xlIjoiYWRtaW4iLCJwZXJtaXNzaW9ucyI6WyIvYWRtaW4vKiJdLCJlbWFpbCI6Im5venN5eXp3QHJvZ2Vycy5jYSIsImlhdCI6MTY5MjExNTExNCwiZXhwIjoxNjkyNjMzNTE0fQ.ehJPmsYH0M28NtxA-LHQkSEt6MXrPoG8dU_bppYG9UE',  # Example authorization header
    'Content-Type': 'application/json',  # Example content-type header
    'url' : '/admin/vehicle'
    
}

api_data = get_api_data(api_url, headers=custom_headers)
if api_data:
    column_names = ['timestamp', 'vin', 'scannerID' , 'StateofCharge(SOC)Display','StateofHealth(SOH)/MaxDeterioration', 'BatteryHeaterTemp2']
    df = pd.DataFrame(np.nan, index=[], columns=column_names)
    for idx, x in enumerate(api_data['data']):
        df.loc[idx+1, 'timestamp'] = x['timestamp']
        df.loc[idx+1, 'vin'] = x['vin']
        df.loc[idx+1, 'scannerID'] = x['scannerID']
        df.loc[idx+1, 'StateofCharge(SOC)Display'] = x['parameterSet']['StateofCharge(SOC)Display ']
        df.loc[idx+1, 'StateofHealth(SOH)/MaxDeterioration'] = x['parameterSet']['StateofHealth(SOH)/MaxDeterioration']
        df.loc[idx+1, 'StateofCharge(SOC)Display'] = x['parameterSet']['StateofCharge(SOC)Display ']
        df.loc[idx+1, 'BatteryHeaterTemp2'] = x['parameterSet']['BatteryHeaterTemp2']
        

        
table_str = tabulate(df, headers='keys', tablefmt='fancy_grid')

print(table_str)
# Out:
# ╒════╤══════════════════════════╤════════════╤═══════════════════╤═════════════════════════════╤═══════════════════════════════════════╤══════════════════════╕
# │    │ timestamp                │ vin        │ scannerID         │   StateofCharge(SOC)Display │   StateofHealth(SOH)/MaxDeterioration │   BatteryHeaterTemp2 │
# ╞════╪══════════════════════════╪════════════╪═══════════════════╪═════════════════════════════╪═══════════════════════════════════════╪══════════════════════╡
# │  1 │ 2023-03-22T10:45:22.721Z │ 5YJ3E1EB9M │ 00:11:27:27:33:11 │                          15 │                                     6 │                   54 │
# ├────┼──────────────────────────┼────────────┼───────────────────┼─────────────────────────────┼───────────────────────────────────────┼──────────────────────┤
# │  2 │ 2023-03-22T10:44:49.239Z │ KNDCC3LG5L │ 00:22:27:27:33:22 │                          66 │                                    13 │                    8 │
# ...
